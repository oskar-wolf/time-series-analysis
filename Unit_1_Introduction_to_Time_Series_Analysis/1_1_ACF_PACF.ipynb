# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
country = "Saudi Arabia"

df_gdp = pd.read_csv('gapminder_gdp.csv', sep=';' , \
    index_col='country')

df_gdp = df_gdp.iloc[:,150:]

gdp_country = df_gdp.loc[country]
gdp_country = gdp_country.dropna()

# %%
gdp_country
# Out:
# 1950    10700
# 1951    11400
# 1952    11800
# 1953    12800
# 1954    14000
#         ...
# 2036    58800
# 2037    59900
# 2038    61200
# 2039    62400
# 2040    63700
# Name: Saudi Arabia, Length: 91, dtype: object

# %%
gdp_country_diff = gdp_country.diff().dropna()
gdp_country_diff.index = gdp_country_diff.index.astype(int)
gdp_country.index=gdp_country.index.astype(int)

# %%
gdp_country
# Out:
# 1950    10700
# 1951    11400
# 1952    11800
# 1953    12800
# 1954    14000
#         ...
# 2036    58800
# 2037    59900
# 2038    61200
# 2039    62400
# 2040    63700
# Name: Saudi Arabia, Length: 91, dtype: object

# %%
gdp_country_diff
# Out:
# 1951     700
# 1952     400
# 1953    1000
# 1954    1200
# 1955       0
#         ...
# 2036    1200
# 2037    1100
# 2038    1300
# 2039    1200
# 2040    1300
# Name: Saudi Arabia, Length: 90, dtype: object

# %%
fig, axes = plt.subplots(2,1 , \
    figsize=(16,10), dpi=100)

plot_acf(gdp_country_diff, alpha=0.05,ax=axes[0], \
    title='Autocorrelation function (ACF)')
axes[0].set_xlabel('Lag')
axes[0].set_ylabel('Correlation')

plot_pacf(gdp_country_diff,alpha=0.05, ax = axes[1], \
    title = 'Partial Autocorrelation function (PACF)')
axes[1].set_xlabel('Lag')
axes[1].set_ylabel('Correlation')
# Out:
# Text(0, 0.5, 'Correlation')
